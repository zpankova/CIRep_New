# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({'num_amount': ['100k', '200k', '300k', '400k', '500k', '600k', '700k', '800k', '900k', '1000k'],
                   'avg_time':   [ 0.038,  0.095,  0.138,  0.174,  0.231,  0.280,  0.322, 0.357 ,  0.412 , 0.42 ]})
sns.lineplot(data=df, x="num_amount", y="avg_time", color = 'pink')
plt.title('График зависимости времени выполнения от кол-ва чисел в файле', fontsize=10)
plt.figure(figsize=(10,5), dpi=300)

# %% [markdown]
# Speed1
# Result "org.example.NPBenchmarks.measure_min":
#   0,038 ±(99.9%) 0,001 s/op [Average]
#   (min, avg, max) = (0,034, 0,038, 0,053), stdev = 0,003
#   CI (99.9%): [0,037, 0,038] (assumes normal distribution)
#
#
# # Run complete. Total time: 00:06:59
#
# Benchmark                 Mode  Cnt  Score   Error  Units
# NPBenchmarks.measure_min  avgt  200  0,038 ± 0,001   s/op
#
# Process finished with exit code 0
#
# Speed2
# Result "org.example.NPBenchmarks.measure_min":
#   0,095 ±(99.9%) 0,009 s/op [Average]
#   (min, avg, max) = (0,066, 0,095, 0,233), stdev = 0,036
#   CI (99.9%): [0,087, 0,104] (assumes normal distribution)
#
#
# # Run complete. Total time: 00:07:13
#
# Benchmark                 Mode  Cnt  Score   Error  Units
# NPBenchmarks.measure_min  avgt  200  0,095 ± 0,009   s/op
#
# Process finished with exit code 0
#
#
#
# Speed3
# Result "org.example.NPBenchmarks.measure_min":
#   0,138 ±(99.9%) 0,004 s/op [Average]
#   (min, avg, max) = (0,103, 0,138, 0,234), stdev = 0,018
#   CI (99.9%): [0,133, 0,142] (assumes normal distribution)
#
#
# # Run complete. Total time: 00:07:19
#
# Benchmark                 Mode  Cnt  Score   Error  Units
# NPBenchmarks.measure_min  avgt  200  0,138 ± 0,004   s/op
#
# Process finished with exit code 0
#
# Speed4
#
# Result "org.example.NPBenchmarks.measure_min":
#   0,174 ±(99.9%) 0,006 s/op [Average]
#   (min, avg, max) = (0,133, 0,174, 0,286), stdev = 0,024
#   CI (99.9%): [0,168, 0,179] (assumes normal distribution)
#
#
# # Run complete. Total time: 00:07:24
#
# Benchmark                 Mode  Cnt  Score   Error  Units
# NPBenchmarks.measure_min  avgt  200  0,174 ± 0,006   s/op
#
# Process finished with exit code 0
#
# Speed5
# Result "org.example.NPBenchmarks.measure_min":
#   0,231 ±(99.9%) 0,008 s/op [Average]
#   (min, avg, max) = (0,195, 0,231, 0,389), stdev = 0,033
#   CI (99.9%): [0,223, 0,239] (assumes normal distribution)
#
#
# # Run complete. Total time: 00:07:33
#
# Benchmark                 Mode  Cnt  Score   Error  Units
# NPBenchmarks.measure_min  avgt  200  0,231 ± 0,008   s/op
#
# Process finished with exit code 0
#
#
# Speed6
# Result "org.example.NPBenchmarks.measure_min":
#   0,280 ±(99.9%) 0,008 s/op [Average]
#   (min, avg, max) = (0,235, 0,280, 0,554), stdev = 0,035
#   CI (99.9%): [0,271, 0,288] (assumes normal distribution)
#
#
# # Run complete. Total time: 00:07:45
#
# Benchmark                 Mode  Cnt  Score   Error  Units
# NPBenchmarks.measure_min  avgt  200  0,280 ± 0,008   s/op
#
# Process finished with exit code 0
#
#
# Speed7
# Result "org.example.NPBenchmarks.measure_min":
#   0,322 ±(99.9%) 0,012 s/op [Average]
#   (min, avg, max) = (0,241, 0,322, 0,549), stdev = 0,050
#   CI (99.9%): [0,310, 0,334] (assumes normal distribution)
#
#
# # Run complete. Total time: 00:08:02
#
# Benchmark                 Mode  Cnt  Score   Error  Units
# NPBenchmarks.measure_min  avgt  200  0,322 ± 0,012   s/op
#
# Process finished with exit code 0
#
#
# Speed8
#
# Result "org.example.NPBenchmarks.measure_min":
#   0,357 ±(99.9%) 0,009 s/op [Average]
#   (min, avg, max) = (0,298, 0,357, 0,550), stdev = 0,037
#   CI (99.9%): [0,348, 0,366] (assumes normal distribution)
#
#
# # Run complete. Total time: 00:08:06
#
# Benchmark                 Mode  Cnt  Score   Error  Units
# NPBenchmarks.measure_min  avgt  200  0,357 ± 0,009   s/op
#
# Process finished with exit code 0
#
# Speed9
# Result "org.example.NPBenchmarks.measure_min":
#   0,412 ±(99.9%) 0,017 s/op [Average]
#   (min, avg, max) = (0,339, 0,412, 0,906), stdev = 0,071
#   CI (99.9%): [0,403, 0,437] (assumes normal distribution)
#
#
# # Run complete. Total time: 00:08:13
#
# Benchmark                 Mode  Cnt  Score   Error  Units
# NPBenchmarks.measure_min  avgt  200  0,412 ± 0,017   s/op
#
# Process finished with exit code 0
#
# Speed10
# Result "org.example.NPBenchmarks.measure_min":
#   0,42 ±(99.9%) 0,031 s/op [Average]
#   (min, avg, max) = (0,288, 0,42, 1,035), stdev = 0,130
#   CI (99.9%): [0,382, 0,443] (assumes normal distribution)
#
#
# # Run complete. Total time: 00:08:20
#
# Benchmark                 Mode  Cnt  Score   Error  Units
# NPBenchmarks.measure_min  avgt  200  0,42 ± 0,031   s/op
#
# Process finished with exit code 0
